# %%
import json
from pyspark import SparkConf,SparkContext

# %%
from pyspark import SparkConf,SparkContext
spark_conf = SparkConf().setMaster("local").setAppName("ReadHbase")
spark_context = SparkContext(conf = spark_conf)
# from pyspark.sql import SparkSession
# spark_session = SparkSession(spark_context)

# %%
hbase_host = "192.168.1.150"
hbase_table = "TEST_RPT"
hbase_conf = {"hbase.zookeeper.quorum": hbase_host,
              "hbase.mapreduce.inputtable": hbase_table,
              "hbase.mapreduce.scan.row.start": '18589802',
              "hbase.mapreduce.scan.row.stop" : '18589812',
              "hbase.mapreduce.scan.columns"  : "info:cont",
              # "hbase.mapreduce.scan.columns"  : "info:cont info:bd info:sex",
             }
              
keyConv = "org.apache.spark.examples.pythonconverters.ImmutableBytesWritableToStringConverter"
valueConv = "org.apache.spark.examples.pythonconverters.HBaseResultToStringConverter"

# %%
hbase_rdd = spark_context.newAPIHadoopRDD("org.apache.hadoop.hbase.mapreduce.TableInputFormat",
                                          "org.apache.hadoop.hbase.io.ImmutableBytesWritable",
                                          "org.apache.hadoop.hbase.client.Result",
                                          keyConverter=keyConv,
                                          valueConverter=valueConv,
                                          conf=hbase_conf,
                                          batchSize=0,
                                         )

# %%
count = hbase_rdd.count()
count
# Out:
# 3

# %%
def report_decode(hbase_string_data):
    decoded_data = json.loads(
        json.loads(
            hbase_string_data
        )['value'].encode().decode('unicode-escape').encode("raw_unicode_escape").decode()
    )
    return decoded_data

# %%
decode_rdd = hbase_rdd.map(lambda xxx:xxx[1])
decode_rdd = decode_rdd.map(lambda xxx:report_decode(xxx))

# %%
print(decode_rdd.collect())
# Out:
# [{'checkItems': [{'checkItemName': '基础项目', 'checkResults': [{'appendInfo': '', 'canExplain': 0, 'checkIndexName': '收缩压', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '148', 'showIndex': None, 'textRef': '', 'unit': 'mmHg'}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '舒张压', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '93', 'showIndex': None, 'textRef': '', 'unit': 'mmHg'}, {'appendInfo': '', 'canExplain': 1, 'checkIndexName': '身高', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '161', 'showIndex': None, 'textRef': '', 'unit': 'Cm'}, {'appendInfo': '', 'canExplain': 1, 'checkIndexName': '体重', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '73.6', 'showIndex': None, 'textRef': '', 'unit': 'kg'}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '体重指数(18.5-23.9)', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '28.40', 'showIndex': None, 'textRef': '', 'unit': ''}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '脉搏（次/分）', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '79', 'showIndex': None, 'textRef': '', 'unit': ''}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '小结', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '体重指数:28.40\n血压:148/93mmHg\n脉搏:79 次/分', 'showIndex': None, 'textRef': '', 'unit': ''}], 'checkStateId': None, 'checkUserName': '张希秋 审核者:柳忠叶', 'departmentName': '', 'salePrice': None}, {'checkItemName': '内科检查', 'checkResults': [{'appendInfo': '', 'canExplain': 0, 'checkIndexName': '既往疾病史', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '无特殊记载', 'showIndex': None, 'textRef': '', 'unit': ''}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '呼吸', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '正常', 'showIndex': None, 'textRef': '', 'unit': ''}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '心率', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '72', 'showIndex': None, 'textRef': '60--100', 'unit': '次/分'}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '心律', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '整齐', 'showIndex': None, 'textRef': '', 'unit': ''}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '心界', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '未见明显异常', 'showIndex': None, 'textRef': '', 'unit': ''}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '心音', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '未见明显异常', 'showIndex': None, 'textRef': '', 'unit': ''}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '心脏杂音', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '未见明显异常', 'showIndex': None, 'textRef': '', 'unit': ''}, {'appendInfo': '', 'canExplain': 0, 'checkIndexName': '肺部检查', 'highValueRef': '', 'isAbandon': None, 'isCalc': None, 'lowValueRef': '', 'resultFlagId': 1, 'resultTypeId': None, 'resultValue': '未见明显异常', 'showIndex': None, 'textRef': '', 'unit': ''}, {'appendInfo': '', 'canExplain': 0, 'checkInde ...

# %%
# hbase_rdd.cache()
output = hbase_rdd.collect()
(row_key, row_value) = output[0]
row_value_dict = json.loads(row_value)
row_value_dict_2 = json.loads(row_value_dict['value'].encode().decode('unicode-escape').encode("raw_unicode_escape").decode())
